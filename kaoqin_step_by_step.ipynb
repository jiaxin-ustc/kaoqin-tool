# %%
import pandas as pd
import numpy as np
from datetime import time, datetime
import gradio as gr
import re

# %%
# 上午打卡时间：8:00之前、12:00之后；
# 下午打卡时间：13:00之前、15:30之后
class AttendanceConfig:
    MORNING_START = time(8, 0)      # 上午上班时间
    MORNING_END = time(12, 0)       # 上午下班时间
    AFTERNOON_START = time(13, 00)  # 下午上班时间
    AFTERNOON_END = time(15, 30)    # 下午下班时间
    ALLOWED_LATE_MINUTES = 0       # 允许迟到分钟数
    ALLOWED_EARLY_MINUTES = 0      # 允许早退分钟数

# %%
def time_add_minutes(t, minutes):
    """时间加减分钟"""
    if not isinstance(t, time):
        return None
    total = t.hour * 60 + t.minute + minutes
    return time(total // 60 % 24, total % 60)

def process_attendance_data(df):
    """处理考勤数据主逻辑"""
    # 提取日期行（假设第3行是日期行）
    date_row = df.iloc[0, 2:].values

    results = []
    for row_idx in range(1, len(df)):
        row = df.iloc[row_idx]
        employee = row[0]
        department = row[1]
        
        for col_idx in range(2, min(len(row), len(date_row)+2)):
            date_str = date_row[col_idx-2]
            print("data_str:",data_str)
            date = f"2025-06-{date_str}" if str(date_str).isdigit() else f"特殊日期_{col_idx}"
            
            # 处理时间数据
            times = process_cell_times(row[col_idx])
            periods = assign_time_periods(times)
            status = check_attendance_status(periods)
            
            record = {
                'employee': employee,
                'department': department,
                'date': date,
                **periods,
                **status
            }
            results.append(record)

    return pd.DataFrame(results)

def parse_time(time_str):
    """将时间字符串转换为time对象"""
    if pd.isna(time_str) or not isinstance(time_str, str):
        return None
    
    try:
        # 清理字符串并提取时间部分
        time_str = re.sub(r'[^\d:]', '', time_str.strip())
        if ':' in time_str:
            parts = time_str.split(':')
            if len(parts) >= 2:
                return time(int(parts[0]), int(parts[1]))
        elif len(time_str) == 4 and time_str.isdigit():
            return time(int(time_str[:2]), int(time_str[2:]))
    except:
        return None
    return None

def process_cell_times(cell_value):
    """处理单元格内的多个时间记录"""
    if pd.isna(cell_value) or cell_value == '':
        return []
    
    # 统一处理换行符和空格
    if isinstance(cell_value, str):
        times = []
        # 先尝试按换行符分割
        for t in cell_value.split('\n'):
            t = t.strip()
            if t:
                # 再尝试按空格分割（处理"07:35 12:08"格式）
                for subt in t.split():
                    parsed = parse_time(subt)
                    if parsed:
                        times.append(parsed)
        return times
    return []

def assign_time_periods(times):
    """
    智能分配时间点到对应时间段（枚举所有情况）
        上午打卡时间：8:00之前、12:00之后；
        下午打卡时间：13:00之前、15:30之后
    """
    config = AttendanceConfig()
    # 过滤无效时间并按时间排序
    valid_times = sorted([t for t in times if isinstance(t, time)])
    print("valid_times:", valid_times)
    num_times = len(valid_times)
    
    # 初始化结果
    result = {
        'morning_start': None,
        'morning_end': None,
        'afternoon_start': None,
        'afternoon_end': None
    }
    
    # 根据时间点数量处理不同情况
    if num_times == 0:
        # 无有效时间点，全部缺卡
        return result
    # MORNING_START 
    elif num_times == 1:
        # 只有一个时间点
        t = valid_times[0]
        if t <= config.MORNING_START:
            result['morning_start'] = t
        elif config.MORNING_END <= t <= config.AFTERNOON_START:
            # 可能在上午下班和下午上班之间
            result['morning_end'] = t
        elif config.AFTERNOON_START < t < config.AFTERNOON_END:
            result['afternoon_start'] = t
        elif t >= config.AFTERNOON_END:
            result['afternoon_end'] = t
        else:
            # 无法确定时间段，按时间顺序分配
            result['morning_start'] = t
    
    elif num_times == 2:
        t1, t2 = valid_times
        print("num_times == 2:",t1, t2)
        print(config.MORNING_START, config.MORNING_END, config.AFTERNOON_START, config.AFTERNOON_END)
        # 可能的情况：上午两次打卡、下午两次打卡、跨午休打卡
        if t1 <= config.MORNING_START and t2 >= config.MORNING_END:
            # 上午两次打卡
            result['morning_start'] = t1
            result['morning_end'] = t2
        elif t1 <= config.AFTERNOON_START and t2 >= config.AFTERNOON_END:
            # 下午两次打卡
            result['afternoon_start'] = t1
            result['afternoon_end'] = t2
        elif t1 < config.MORNING_END and t2 > config.AFTERNOON_START:
            # 跨午休打卡
            result['morning_end'] = t1
            result['afternoon_start'] = t2
        else:
            # 默认分配
            result['morning_start'] = t1
            result['morning_end'] = t2
    
    elif num_times == 3:
        t1, t2, t3 = valid_times
        # 可能缺上午上班、上午下班、下午上班或下午下班
        if t1 <= config.MORNING_START and t2 >= config.MORNING_END and t3 >= config.AFTERNOON_END:
            # 缺下午上班
            result['morning_start'] = t1
            result['morning_end'] = t2
            result['afternoon_end'] = t3
        elif t1 <= config.MORNING_START and t2 <= config.AFTERNOON_START and t3 >= config.AFTERNOON_END:
            # 缺上午下班
            result['morning_start'] = t1
            result['afternoon_start'] = t2
            result['afternoon_end'] = t3
        elif t1 >= config.MORNING_END and t2 <= config.AFTERNOON_START and t3 >= config.AFTERNOON_END:
            # 缺上午上班
            result['morning_end'] = t1
            result['afternoon_start'] = t2
            result['afternoon_end'] = t3
        elif t1 <= config.MORNING_START and t2 >= config.MORNING_END and t3 <= config.AFTERNOON_START:
            # 缺下午下班
            result['morning_start'] = t1
            result['morning_end'] = t2
            result['afternoon_start'] = t3
        else:
            # 默认分配
            result['morning_start'] = t1
            result['morning_end'] = t2
            result['afternoon_start'] = t3
    
    elif num_times >= 4:
        # 有4个或更多时间点，取前4个
        t1, t2, t3, t4 = valid_times[:4]
        result['morning_start'] = t1
        result['morning_end'] = t2
        result['afternoon_start'] = t3
        result['afternoon_end'] = t4
    
    return result

def check_attendance_status(record):
    """检查考勤状态（优化版）"""
    config = AttendanceConfig()
    status = {
        'late': False,
        'early_leave': False,
        'missing': False,
        'status_details': []
    }
    
    # 检查上午上班
    if record['morning_start']:
        if record['morning_start'] > time_add_minutes(config.MORNING_START, config.ALLOWED_LATE_MINUTES):
            status['late'] = True
            status['status_details'].append('上午迟到')
    else:
        status['missing'] = True
        status['status_details'].append('上午上班缺卡')
    
    # 检查上午下班
    if record['morning_end']:
        if record['morning_end'] < time_add_minutes(config.MORNING_END, -config.ALLOWED_EARLY_MINUTES):
            status['early_leave'] = True
            status['status_details'].append('上午早退')
    else:
        status['missing'] = True
        status['status_details'].append('上午下班缺卡')
    
    # 检查下午上班
    if record['afternoon_start']:
        if record['afternoon_start'] > time_add_minutes(config.AFTERNOON_START, config.ALLOWED_LATE_MINUTES):
            status['late'] = True
            status['status_details'].append('下午迟到')
    else:
        status['missing'] = True
        status['status_details'].append('下午上班缺卡')
    
    # 检查下午下班
    if record['afternoon_end']:
        if record['afternoon_end'] < time_add_minutes(config.AFTERNOON_END, -config.ALLOWED_EARLY_MINUTES):
            status['early_leave'] = True
            status['status_details'].append('下午早退')
    else:
        status['missing'] = True
        status['status_details'].append('下午下班缺卡')
    
    return status

# %%
##给df的前两列加上列名：“姓名”，“部门”
input_file = "./工作簿2.xlsx"
df = pd.read_excel(input_file, header=3) #, columns=["姓名", "部门"]skiprows=3,
print(df.columns)
df = df.rename(columns={'Unnamed: 0': '姓名', 'Unnamed: 1': '部门'})
# print("df.head(2):",df.head(2))
df.head(7)
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', '日', '2', '3', '4', '5', '6', '六', '日.1',
#        '9', '10', '11', '12', '13', '六.1', '日.2', '16', '17', '18', '19', '20',
#        '六.2', '日.3', '23', '24', '25', '26', '27', '六.3', '日.4', '30'],
#       dtype='object')
#     姓名   部门                 日                                   2  \
# 0   刘旸  财务部               NaN  07:35  \n12:08  \n12:31  \n17:31
# 1  沈宝玉  财务部               NaN  07:50  \n12:14  \n12:31  \n17:37
# 2   施军  财务部               NaN                    07:48  \n17:38
# 3  谭益云  财务部               NaN  07:58  \n12:00  \n13:29  \n17:37
# 4   袁政  财务部               NaN  07:46  \n12:10  \n13:26  \n18:13
# 5   刘军  采购部               NaN  07:51  \n12:14  \n12:32  \n17:48
# 6  刘学义  采购部  07:45  \n11:00    07:39  \n12:05  \n13:26  \n17:34
#
#                                     3                                   4  \
# 0  07:35  \n12:12  \n12:32  \n17:33    07:35  \n12:11  \n12:31  \n17:33
# 1  07:48  \n12:13  \n12:31  \n17:41    07:50  \n12:11  \n12:31  \n17:42
# 2                    13:42  \n17:33                      13:44  \n17:33
# 3  08:01  \n12:10  \n13:28  \n17:33    07:55  \n12:17  \n13:29  \n17:36
# 4  07:58  \n12:15  \n13:25  \n17:39    07:54  \n12:01  \n13:26  \n17:38
# 5  07:54  \n12:19  \n12:30  \n17:40    07:55  \n12:23  \n12:32  \n18:10
# 6  07:44  \n12:00  \n13:31  \n17:35    07:48  \n12:01  \n13:30  \n17:34
#
#                                     5                                   6  \
# 0  07:40  \n12:11  \n12:31  \n17:32    07:32  \n12:11  \n12:32  \n17:32
# 1  07:54  \n12:11  \n12:32  \n17:41    07:55  \n12:10  \n12:32  \n17:36
# 2  09:53  \n12:02  \n13:27  \n17:34                      14:31  \n17:32
# 3  07:59  \n12:02  \n13:28  \n17:31    07:55  \n12:29  \n12:30  \n17:32
# 4                                 NaN  07:56  \n12:06  \n13:25  \n17:33
# 5  07:54  \n12:19  \n12:30  \n17:52    07:40  \n12:18  \n12:30  \n18:07
# 6  07:51  \n12:09  \n13:26  \n17:32    07:44  \n12:05  \n12:34  \n17:35
#
#                                     六                                 日.1  \
# 0  07:38  \n12:12  \n12:32  \n17:33                                   NaN
# 1  07:53  \n12:12  \n12:32  \n17:38                                   NaN
# 2                    13:35  \n17:36                                   NaN
# 3  08:03  \n12:00  \n12:32  \n17:40                                   NaN
# 4  07:47  \n12:00  \n13:24  \n17:42                                   NaN
# 5  07:36  \n12:23  \n12:30  \n17:49                                   NaN
# 6                                 NaN  07:48  \n12:24  \n13:31  \n17:35
#
#    ...                                 六.2  \
# 0  ...  07:27  \n12:01  \n12:32  \n17:34
# 1  ...  07:54  \n12:04  \n12:32  \n17:44
# 2  ...                    14:27  \n17:31
# 3  ...  07:58  \n12:00  \n13:26  \n17:32
# 4  ...  07:49  \n12:00  \n13:25  \n18:07
# 5  ...  07:36  \n12:04  \n12:32  \n18:09
# 6  ...                                 NaN
#
#                                   日.3  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6  07:57  \n12:01  \n13:28  \n17:01
#
#                                             23  \
# 0           07:27  \n12:04  \n12:31  \n17:33
# 1           07:41  \n12:04  \n12:32  \n17:35
# 2                             13:39  \n17:33
# 3           07:59  \n12:02  \n13:29  \n17:44
# 4           07:49  \n12:04  \n13:25  \n19:06
# 5           07:56  \n12:08  \n12:32  \n17:57
# 6  07:54  \n12:03  \n12:40  \n13:05  \n17:37
#
#                                    24                                  25  \
# 0  07:31  \n12:05  \n12:31  \n17:34    07:31  \n12:04  \n12:32  \n17:34
# 1  07:55  \n12:05  \n12:31  \n17:37    07:54  \n12:03  \n12:32  \n17:32
# 2                    13:30  \n17:32                      12:52  \n17:34
# 3                    13:25  \n17:32    07:59  \n12:02  \n13:28  \n17:34
# 4  07:54  \n12:09  \n13:24  \n17:44    07:59  \n12:02  \n13:25  \n18:01
# 5  07:48  \n12:06  \n12:31  \n17:58    07:52  \n12:08  \n12:31  \n17:41
# 6  07:50  \n12:12  \n12:44  \n17:39             07:52  \n12:17  \n17:41
#
#                                    26                                  27  \
# 0  07:37  \n12:03  \n12:31  \n17:32    07:35  \n12:03  \n12:31  \n17:32
# 1  07:55  \n12:03  \n12:31  \n17:38    07:52  \n12:03  \n12:32  \n17:38
# 2                    13:45  \n17:31                      13:35  \n17:33
# 3  07:52  \n12:23  \n13:09  \n17:32    08:00  \n12:00  \n12:38  \n17:30
# 4  07:44  \n12:03  \n13:26  \n18:44    07:55  \n12:03  \n13:26  \n17:57
# 5  07:49  \n12:06  \n12:35  \n17:54    07:53  \n12:09  \n12:34  \n17:46
# 6  07:51  \n12:09  \n12:40  \n17:35    07:52  \n12:03  \n12:45  \n17:32
#
#                                   六.3      日.4  \
# 0  07:29  \n12:01  \n12:31  \n17:33        NaN
# 1  07:56  \n12:02  \n12:32  \n17:40        NaN
# 2                    13:35  \n17:37        NaN
# 3  07:57  \n12:00  \n12:31  \n17:36        NaN
# 4  07:50  \n12:01  \n13:25  \n17:47        NaN
# 5  07:32  \n12:27  \n12:38  \n17:50        NaN
# 6  07:55  \n12:12  \n12:35  \n17:43    06:42
#
#                                    30
# 0  07:28  \n12:03  \n12:31  \n17:32
# 1  07:55  \n12:03  \n12:32  \n17:39
# 2                    14:16  \n17:32
# 3  07:55  \n12:29  \n12:30  \n17:51
# 4  07:46  \n12:03  \n13:25  \n17:33
# 5  07:51  \n12:09  \n12:36  \n17:55
# 6  07:53  \n12:02  \n12:44  \n17:32
#
# [7 rows x 32 columns]

# %%
df.columns.values
# Out:
# array(['姓名', '部门', '日', '2', '3', '4', '5', '6', '六', '日.1', '9', '10',
#        '11', '12', '13', '六.1', '日.2', '16', '17', '18', '19', '20',
#        '六.2', '日.3', '23', '24', '25', '26', '27', '六.3', '日.4', '30'],
#       dtype=object)

# %%
df
# 提取日期行（假设第3行是日期行）
date_row = df.columns.values[2:]#df.iloc[0, 2:].values
date_row
# Out:
# array(['日', '2', '3', '4', '5', '6', '六', '日.1', '9', '10', '11', '12',
#        '13', '六.1', '日.2', '16', '17', '18', '19', '20', '六.2', '日.3',
#        '23', '24', '25', '26', '27', '六.3', '日.4', '30'], dtype=object)

# %%
results = []
for row_idx in range(0, len(df)):
    row = df.iloc[row_idx]
    employee = row[0]
    department = row[1]
    
    for col_idx in range(2, min(len(row), len(date_row)+2)):
        date_str = date_row[col_idx-2]
        print("date_str:",date_str)
        date = f"2025-06-{date_str}" if str(date_str).isdigit() else f"特殊日期_{col_idx}" ###需要去掉
        print("date:",date)
        
        # 处理时间数据
        times = process_cell_times(row[col_idx])
        print("times:",times)
        periods = assign_time_periods(times)
        print("periods:",periods)
        status = check_attendance_status(periods)
        print("status:",status)
        
        record = {
            'employee': employee,
            'department': department,
            'date': date,
            **periods,
            **status
        }
        print("record:",record)
        results.append(record)
        print()
# Out:
# date_str: 日
# date: 特殊日期_2
# times: []
# valid_times: []
# periods: {'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '特殊日期_2', 'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None, 'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 2
# date: 2025-06-2
# times: [datetime.time(7, 35), datetime.time(12, 8), datetime.time(12, 31), datetime.time(17, 31)]
# valid_times: [datetime.time(7, 35), datetime.time(12, 8), datetime.time(12, 31), datetime.time(17, 31)]
# periods: {'morning_start': datetime.time(7, 35), 'morning_end': datetime.time(12, 8), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 31)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-2', 'morning_start': datetime.time(7, 35), 'morning_end': datetime.time(12, 8), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 31), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 3
# date: 2025-06-3
# times: [datetime.time(7, 35), datetime.time(12, 12), datetime.time(12, 32), datetime.time(17, 33)]
# valid_times: [datetime.time(7, 35), datetime.time(12, 12), datetime.time(12, 32), datetime.time(17, 33)]
# periods: {'morning_start': datetime.time(7, 35), 'morning_end': datetime.time(12, 12), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 33)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-3', 'morning_start': datetime.time(7, 35), 'morning_end': datetime.time(12, 12), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 33), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 4
# date: 2025-06-4
# times: [datetime.time(7, 35), datetime.time(12, 11), datetime.time(12, 31), datetime.time(17, 33)]
# valid_times: [datetime.time(7, 35), datetime.time(12, 11), datetime.time(12, 31), datetime.time(17, 33)]
# periods: {'morning_start': datetime.time(7, 35), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 33)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-4', 'morning_start': datetime.time(7, 35), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 33), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 5
# date: 2025-06-5
# times: [datetime.time(7, 40), datetime.time(12, 11), datetime.time(12, 31), datetime.time(17, 32)]
# valid_times: [datetime.time(7, 40), datetime.time(12, 11), datetime.time(12, 31), datetime.time(17, 32)]
# periods: {'morning_start': datetime.time(7, 40), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 32)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-5', 'morning_start': datetime.time(7, 40), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 32), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 6
# date: 2025-06-6
# times: [datetime.time(7, 32), datetime.time(12, 11), datetime.time(12, 32), datetime.time(17, 32)]
# valid_times: [datetime.time(7, 32), datetime.time(12, 11), datetime.time(12, 32), datetime.time(17, 32)]
# periods: {'morning_start': datetime.time(7, 32), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 32)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-6', 'morning_start': datetime.time(7, 32), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 32), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 六
# date: 特殊日期_8
# times: [datetime.time(7, 38), datetime.time(12, 12), datetime.time(12, 32), datetime.time(17, 33)]
# valid_times: [datetime.time(7, 38), datetime.time(12, 12), datetime.time(12, 32), datetime.time(17, 33)]
# periods: {'morning_start': datetime.time(7, 38), 'morning_end': datetime.time(12, 12), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 33)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '特殊日期_8', 'morning_start': datetime.time(7, 38), 'morning_end': datetime.time(12, 12), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 33), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 日.1
# date: 特殊日期_9
# times: []
# valid_times: []
# periods: {'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '特殊日期_9', 'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None, 'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 9
# date: 2025-06-9
# times: [datetime.time(7, 38), datetime.time(12, 10), datetime.time(12, 32), datetime.time(17, 33)]
# valid_times: [datetime.time(7, 38), datetime.time(12, 10), datetime.time(12, 32), datetime.time(17, 33)]
# periods: {'morning_start': datetime.time(7, 38), 'morning_end': datetime.time(12, 10), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 33)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-9', 'morning_start': datetime.time(7, 38), 'morning_end': datetime.time(12, 10), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 33), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 10
# date: 2025-06-10
# times: [datetime.time(7, 34), datetime.time(12, 11), datetime.time(12, 32), datetime.time(17, 32)]
# valid_times: [datetime.time(7, 34), datetime.time(12, 11), datetime.time(12, 32), datetime.time(17, 32)]
# periods: {'morning_start': datetime.time(7, 34), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 32)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-10', 'morning_start': datetime.time(7, 34), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 32), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 11
# date: 2025-06-11
# times: [datetime.time(7, 32), datetime.time(12, 14), datetime.time(12, 32), datetime.time(17, 33)]
# valid_times: [datetime.time(7, 32), datetime.time(12, 14), datetime.time(12, 32), datetime.time(17, 33)]
# periods: {'morning_start': datetime.time(7, 32), 'morning_end': datetime.time(12, 14), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 33)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-11', 'morning_start': datetime.time(7, 32), 'morning_end': datetime.time(12, 14), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 33), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 12
# date: 2025-06-12
# times: [datetime.time(7, 40), datetime.time(12, 9), datetime.time(12, 32), datetime.time(17, 32)]
# valid_times: [datetime.time(7, 40), datetime.time(12, 9), datetime.time(12, 32), datetime.time(17, 32)]
# periods: {'morning_start': datetime.time(7, 40), 'morning_end': datetime.time(12, 9), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 32)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-12', 'morning_start': datetime.time(7, 40), 'morning_end': datetime.time(12, 9), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 32), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 13
# date: 2025-06-13
# times: [datetime.time(7, 31), datetime.time(12, 8), datetime.time(12, 31), datetime.time(17, 32)]
# valid_times: [datetime.time(7, 31), datetime.time(12, 8), datetime.time(12, 31), datetime.time(17, 32)]
# periods: {'morning_start': datetime.time(7, 31), 'morning_end': datetime.time(12, 8), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 32)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-13', 'morning_start': datetime.time(7, 31), 'morning_end': datetime.time(12, 8), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 32), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 六.1
# date: 特殊日期_15
# times: [datetime.time(7, 31), datetime.time(12, 19), datetime.time(12, 31), datetime.time(17, 32)]
# valid_times: [datetime.time(7, 31), datetime.time(12, 19), datetime.time(12, 31), datetime.time(17, 32)]
# periods: {'morning_start': datetime.time(7, 31), 'morning_end': datetime.time(12, 19), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 32)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '特殊日期_15', 'morning_start': datetime.time(7, 31), 'morning_end': datetime.time(12, 19), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 32), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 日.2
# date: 特殊日期_16
# times: []
# valid_times: []
# periods: {'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '特殊日期_16', 'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None, 'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 16
# date: 2025-06-16
# times: [datetime.time(7, 33), datetime.time(12, 10), datetime.time(12, 32), datetime.time(17, 33)]
# valid_times: [datetime.time(7, 33), datetime.time(12, 10), datetime.time(12, 32), datetime.time(17, 33)]
# periods: {'morning_start': datetime.time(7, 33), 'morning_end': datetime.time(12, 10), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 33)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-16', 'morning_start': datetime.time(7, 33), 'morning_end': datetime.time(12, 10), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 33), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 17
# date: 2025-06-17
# times: [datetime.time(7, 37), datetime.time(12, 1), datetime.time(12, 31), datetime.time(17, 34)]
# valid_times: [datetime.time(7, 37), datetime.time(12, 1), datetime.time(12, 31), datetime.time(17, 34)]
# periods: {'morning_start': datetime.time(7, 37), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 34)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-17', 'morning_start': datetime.time(7, 37), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 34), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 18
# date: 2025-06-18
# times: [datetime.time(7, 31), datetime.time(12, 1), datetime.time(12, 32), datetime.time(17, 32)]
# valid_times: [datetime.time(7, 31), datetime.time(12, 1), datetime.time(12, 32), datetime.time(17, 32)]
# periods: {'morning_start': datetime.time(7, 31), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 32)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-18', 'morning_start': datetime.time(7, 31), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 32), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 19
# date: 2025-06-19
# times: [datetime.time(7, 38), datetime.time(12, 3), datetime.time(12, 31), datetime.time(17, 33)]
# valid_times: [datetime.time(7, 38), datetime.time(12, 3), datetime.time(12, 31), datetime.time(17, 33)]
# periods: {'morning_start': datetime.time(7, 38), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 33)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-19', 'morning_start': datetime.time(7, 38), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 33), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 20
# date: 2025-06-20
# times: [datetime.time(7, 32), datetime.time(12, 3), datetime.time(12, 32), datetime.time(17, 33)]
# valid_times: [datetime.time(7, 32), datetime.time(12, 3), datetime.time(12, 32), datetime.time(17, 33)]
# periods: {'morning_start': datetime.time(7, 32), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 33)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-20', 'morning_start': datetime.time(7, 32), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 33), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 六.2
# date: 特殊日期_22
# times: [datetime.time(7, 27), datetime.time(12, 1), datetime.time(12, 32), datetime.time(17, 34)]
# valid_times: [datetime.time(7, 27), datetime.time(12, 1), datetime.time(12, 32), datetime.time(17, 34)]
# periods: {'morning_start': datetime.time(7, 27), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 34)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '特殊日期_22', 'morning_start': datetime.time(7, 27), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 34), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 日.3
# date: 特殊日期_23
# times: []
# valid_times: []
# periods: {'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '特殊日期_23', 'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None, 'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 23
# date: 2025-06-23
# times: [datetime.time(7, 27), datetime.time(12, 4), datetime.time(12, 31), datetime.time(17, 33)]
# valid_times: [datetime.time(7, 27), datetime.time(12, 4), datetime.time(12, 31), datetime.time(17, 33)]
# periods: {'morning_start': datetime.time(7, 27), 'morning_end': datetime.time(12, 4), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 33)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-23', 'morning_start': datetime.time(7, 27), 'morning_end': datetime.time(12, 4), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 33), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 24
# date: 2025-06-24
# times: [datetime.time(7, 31), datetime.time(12, 5), datetime.time(12, 31), datetime.time(17, 34)]
# valid_times: [datetime.time(7, 31), datetime.time(12, 5), datetime.time(12, 31), datetime.time(17, 34)]
# periods: {'morning_start': datetime.time(7, 31), 'morning_end': datetime.time(12, 5), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 34)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-24', 'morning_start': datetime.time(7, 31), 'morning_end': datetime.time(12, 5), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 34), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 25
# date: 2025-06-25
# times: [datetime.time(7, 31), datetime.time(12, 4), datetime.time(12, 32), datetime.time(17, 34)]
# valid_times: [datetime.time(7, 31), datetime.time(12, 4), datetime.time(12, 32), datetime.time(17, 34)]
# periods: {'morning_start': datetime.time(7, 31), 'morning_end': datetime.time(12, 4), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 34)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-25', 'morning_start': datetime.time(7, 31), 'morning_end': datetime.time(12, 4), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 34), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 26
# date: 2025-06-26
# times: [datetime.time(7, 37), datetime.time(12, 3), datetime.time(12, 31), datetime.time(17, 32)]
# valid_times: [datetime.time(7, 37), datetime.time(12, 3), datetime.time(12, 31), datetime.time(17, 32)]
# periods: {'morning_start': datetime.time(7, 37), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 32)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-26', 'morning_start': datetime.time(7, 37), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 32), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 27
# date: 2025-06-27
# times: [datetime.time(7, 35), datetime.time(12, 3), datetime.time(12, 31), datetime.time(17, 32)]
# valid_times: [datetime.time(7, 35), datetime.time(12, 3), datetime.time(12, 31), datetime.time(17, 32)]
# periods: {'morning_start': datetime.time(7, 35), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 32)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-27', 'morning_start': datetime.time(7, 35), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 32), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 六.3
# date: 特殊日期_29
# times: [datetime.time(7, 29), datetime.time(12, 1), datetime.time(12, 31), datetime.time(17, 33)]
# valid_times: [datetime.time(7, 29), datetime.time(12, 1), datetime.time(12, 31), datetime.time(17, 33)]
# periods: {'morning_start': datetime.time(7, 29), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 33)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '特殊日期_29', 'morning_start': datetime.time(7, 29), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 33), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 日.4
# date: 特殊日期_30
# times: []
# valid_times: []
# periods: {'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '特殊日期_30', 'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None, 'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 30
# date: 2025-06-30
# times: [datetime.time(7, 28), datetime.time(12, 3), datetime.time(12, 31), datetime.time(17, 32)]
# valid_times: [datetime.time(7, 28), datetime.time(12, 3), datetime.time(12, 31), datetime.time(17, 32)]
# periods: {'morning_start': datetime.time(7, 28), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 32)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '刘旸', 'department': '财务部', 'date': '2025-06-30', 'morning_start': datetime.time(7, 28), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 32), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 日
# date: 特殊日期_2
# times: []
# valid_times: []
# periods: {'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '特殊日期_2', 'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None, 'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 2
# date: 2025-06-2
# times: [datetime.time(7, 50), datetime.time(12, 14), datetime.time(12, 31), datetime.time(17, 37)]
# valid_times: [datetime.time(7, 50), datetime.time(12, 14), datetime.time(12, 31), datetime.time(17, 37)]
# periods: {'morning_start': datetime.time(7, 50), 'morning_end': datetime.time(12, 14), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 37)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-2', 'morning_start': datetime.time(7, 50), 'morning_end': datetime.time(12, 14), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 37), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 3
# date: 2025-06-3
# times: [datetime.time(7, 48), datetime.time(12, 13), datetime.time(12, 31), datetime.time(17, 41)]
# valid_times: [datetime.time(7, 48), datetime.time(12, 13), datetime.time(12, 31), datetime.time(17, 41)]
# periods: {'morning_start': datetime.time(7, 48), 'morning_end': datetime.time(12, 13), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 41)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-3', 'morning_start': datetime.time(7, 48), 'morning_end': datetime.time(12, 13), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 41), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 4
# date: 2025-06-4
# times: [datetime.time(7, 50), datetime.time(12, 11), datetime.time(12, 31), datetime.time(17, 42)]
# valid_times: [datetime.time(7, 50), datetime.time(12, 11), datetime.time(12, 31), datetime.time(17, 42)]
# periods: {'morning_start': datetime.time(7, 50), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 42)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-4', 'morning_start': datetime.time(7, 50), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 42), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 5
# date: 2025-06-5
# times: [datetime.time(7, 54), datetime.time(12, 11), datetime.time(12, 32), datetime.time(17, 41)]
# valid_times: [datetime.time(7, 54), datetime.time(12, 11), datetime.time(12, 32), datetime.time(17, 41)]
# periods: {'morning_start': datetime.time(7, 54), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 41)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-5', 'morning_start': datetime.time(7, 54), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 41), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 6
# date: 2025-06-6
# times: [datetime.time(7, 55), datetime.time(12, 10), datetime.time(12, 32), datetime.time(17, 36)]
# valid_times: [datetime.time(7, 55), datetime.time(12, 10), datetime.time(12, 32), datetime.time(17, 36)]
# periods: {'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 10), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 36)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-6', 'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 10), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 36), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 六
# date: 特殊日期_8
# times: [datetime.time(7, 53), datetime.time(12, 12), datetime.time(12, 32), datetime.time(17, 38)]
# valid_times: [datetime.time(7, 53), datetime.time(12, 12), datetime.time(12, 32), datetime.time(17, 38)]
# periods: {'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 12), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 38)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '特殊日期_8', 'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 12), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 38), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 日.1
# date: 特殊日期_9
# times: []
# valid_times: []
# periods: {'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '特殊日期_9', 'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None, 'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 9
# date: 2025-06-9
# times: [datetime.time(7, 52), datetime.time(12, 9), datetime.time(12, 32), datetime.time(17, 43)]
# valid_times: [datetime.time(7, 52), datetime.time(12, 9), datetime.time(12, 32), datetime.time(17, 43)]
# periods: {'morning_start': datetime.time(7, 52), 'morning_end': datetime.time(12, 9), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 43)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-9', 'morning_start': datetime.time(7, 52), 'morning_end': datetime.time(12, 9), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 43), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 10
# date: 2025-06-10
# times: [datetime.time(7, 52), datetime.time(12, 11), datetime.time(12, 32), datetime.time(17, 36)]
# valid_times: [datetime.time(7, 52), datetime.time(12, 11), datetime.time(12, 32), datetime.time(17, 36)]
# periods: {'morning_start': datetime.time(7, 52), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 36)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-10', 'morning_start': datetime.time(7, 52), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 36), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 11
# date: 2025-06-11
# times: [datetime.time(7, 55), datetime.time(12, 14), datetime.time(12, 32), datetime.time(17, 45)]
# valid_times: [datetime.time(7, 55), datetime.time(12, 14), datetime.time(12, 32), datetime.time(17, 45)]
# periods: {'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 14), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 45)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-11', 'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 14), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 45), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 12
# date: 2025-06-12
# times: [datetime.time(7, 55), datetime.time(12, 8), datetime.time(12, 32), datetime.time(17, 39)]
# valid_times: [datetime.time(7, 55), datetime.time(12, 8), datetime.time(12, 32), datetime.time(17, 39)]
# periods: {'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 8), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 39)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-12', 'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 8), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 39), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 13
# date: 2025-06-13
# times: [datetime.time(7, 51), datetime.time(12, 10), datetime.time(12, 31), datetime.time(17, 40)]
# valid_times: [datetime.time(7, 51), datetime.time(12, 10), datetime.time(12, 31), datetime.time(17, 40)]
# periods: {'morning_start': datetime.time(7, 51), 'morning_end': datetime.time(12, 10), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 40)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-13', 'morning_start': datetime.time(7, 51), 'morning_end': datetime.time(12, 10), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 40), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 六.1
# date: 特殊日期_15
# times: [datetime.time(7, 50), datetime.time(12, 11), datetime.time(12, 32), datetime.time(17, 40)]
# valid_times: [datetime.time(7, 50), datetime.time(12, 11), datetime.time(12, 32), datetime.time(17, 40)]
# periods: {'morning_start': datetime.time(7, 50), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 40)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '特殊日期_15', 'morning_start': datetime.time(7, 50), 'morning_end': datetime.time(12, 11), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 40), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 日.2
# date: 特殊日期_16
# times: []
# valid_times: []
# periods: {'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '特殊日期_16', 'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None, 'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 16
# date: 2025-06-16
# times: [datetime.time(7, 47), datetime.time(12, 10), datetime.time(12, 32), datetime.time(17, 34)]
# valid_times: [datetime.time(7, 47), datetime.time(12, 10), datetime.time(12, 32), datetime.time(17, 34)]
# periods: {'morning_start': datetime.time(7, 47), 'morning_end': datetime.time(12, 10), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 34)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-16', 'morning_start': datetime.time(7, 47), 'morning_end': datetime.time(12, 10), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 34), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 17
# date: 2025-06-17
# times: [datetime.time(7, 54), datetime.time(12, 1), datetime.time(12, 33), datetime.time(17, 35)]
# valid_times: [datetime.time(7, 54), datetime.time(12, 1), datetime.time(12, 33), datetime.time(17, 35)]
# periods: {'morning_start': datetime.time(7, 54), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 33), 'afternoon_end': datetime.time(17, 35)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-17', 'morning_start': datetime.time(7, 54), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 33), 'afternoon_end': datetime.time(17, 35), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 18
# date: 2025-06-18
# times: [datetime.time(7, 49), datetime.time(12, 16), datetime.time(12, 31), datetime.time(17, 39)]
# valid_times: [datetime.time(7, 49), datetime.time(12, 16), datetime.time(12, 31), datetime.time(17, 39)]
# periods: {'morning_start': datetime.time(7, 49), 'morning_end': datetime.time(12, 16), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 39)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-18', 'morning_start': datetime.time(7, 49), 'morning_end': datetime.time(12, 16), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 39), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 19
# date: 2025-06-19
# times: [datetime.time(7, 56), datetime.time(12, 3), datetime.time(12, 31), datetime.time(17, 39)]
# valid_times: [datetime.time(7, 56), datetime.time(12, 3), datetime.time(12, 31), datetime.time(17, 39)]
# periods: {'morning_start': datetime.time(7, 56), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 39)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-19', 'morning_start': datetime.time(7, 56), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 39), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 20
# date: 2025-06-20
# times: [datetime.time(7, 48), datetime.time(12, 3), datetime.time(12, 32), datetime.time(17, 40)]
# valid_times: [datetime.time(7, 48), datetime.time(12, 3), datetime.time(12, 32), datetime.time(17, 40)]
# periods: {'morning_start': datetime.time(7, 48), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 40)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-20', 'morning_start': datetime.time(7, 48), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 40), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 六.2
# date: 特殊日期_22
# times: [datetime.time(7, 54), datetime.time(12, 4), datetime.time(12, 32), datetime.time(17, 44)]
# valid_times: [datetime.time(7, 54), datetime.time(12, 4), datetime.time(12, 32), datetime.time(17, 44)]
# periods: {'morning_start': datetime.time(7, 54), 'morning_end': datetime.time(12, 4), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 44)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '特殊日期_22', 'morning_start': datetime.time(7, 54), 'morning_end': datetime.time(12, 4), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 44), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 日.3
# date: 特殊日期_23
# times: []
# valid_times: []
# periods: {'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '特殊日期_23', 'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None, 'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 23
# date: 2025-06-23
# times: [datetime.time(7, 41), datetime.time(12, 4), datetime.time(12, 32), datetime.time(17, 35)]
# valid_times: [datetime.time(7, 41), datetime.time(12, 4), datetime.time(12, 32), datetime.time(17, 35)]
# periods: {'morning_start': datetime.time(7, 41), 'morning_end': datetime.time(12, 4), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 35)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-23', 'morning_start': datetime.time(7, 41), 'morning_end': datetime.time(12, 4), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 35), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 24
# date: 2025-06-24
# times: [datetime.time(7, 55), datetime.time(12, 5), datetime.time(12, 31), datetime.time(17, 37)]
# valid_times: [datetime.time(7, 55), datetime.time(12, 5), datetime.time(12, 31), datetime.time(17, 37)]
# periods: {'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 5), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 37)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-24', 'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 5), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 37), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 25
# date: 2025-06-25
# times: [datetime.time(7, 54), datetime.time(12, 3), datetime.time(12, 32), datetime.time(17, 32)]
# valid_times: [datetime.time(7, 54), datetime.time(12, 3), datetime.time(12, 32), datetime.time(17, 32)]
# periods: {'morning_start': datetime.time(7, 54), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 32)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-25', 'morning_start': datetime.time(7, 54), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 32), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 26
# date: 2025-06-26
# times: [datetime.time(7, 55), datetime.time(12, 3), datetime.time(12, 31), datetime.time(17, 38)]
# valid_times: [datetime.time(7, 55), datetime.time(12, 3), datetime.time(12, 31), datetime.time(17, 38)]
# periods: {'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 38)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-26', 'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 38), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 27
# date: 2025-06-27
# times: [datetime.time(7, 52), datetime.time(12, 3), datetime.time(12, 32), datetime.time(17, 38)]
# valid_times: [datetime.time(7, 52), datetime.time(12, 3), datetime.time(12, 32), datetime.time(17, 38)]
# periods: {'morning_start': datetime.time(7, 52), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 38)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-27', 'morning_start': datetime.time(7, 52), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 38), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 六.3
# date: 特殊日期_29
# times: [datetime.time(7, 56), datetime.time(12, 2), datetime.time(12, 32), datetime.time(17, 40)]
# valid_times: [datetime.time(7, 56), datetime.time(12, 2), datetime.time(12, 32), datetime.time(17, 40)]
# periods: {'morning_start': datetime.time(7, 56), 'morning_end': datetime.time(12, 2), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 40)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '特殊日期_29', 'morning_start': datetime.time(7, 56), 'morning_end': datetime.time(12, 2), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 40), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 日.4
# date: 特殊日期_30
# times: []
# valid_times: []
# periods: {'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '特殊日期_30', 'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None, 'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 30
# date: 2025-06-30
# times: [datetime.time(7, 55), datetime.time(12, 3), datetime.time(12, 32), datetime.time(17, 39)]
# valid_times: [datetime.time(7, 55), datetime.time(12, 3), datetime.time(12, 32), datetime.time(17, 39)]
# periods: {'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 39)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '沈宝玉', 'department': '财务部', 'date': '2025-06-30', 'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 3), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 39), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 日
# date: 特殊日期_2
# times: []
# valid_times: []
# periods: {'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '施军', 'department': '财务部', 'date': '特殊日期_2', 'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None, 'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 2
# date: 2025-06-2
# times: [datetime.time(7, 48), datetime.time(17, 38)]
# valid_times: [datetime.time(7, 48), datetime.time(17, 38)]
# num_times == 2: 07:48:00 17:38:00
# 08:00:00 12:00:00 13:00:00 15:30:00
# periods: {'morning_start': datetime.time(7, 48), 'morning_end': datetime.time(17, 38), 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': False, 'early_leave': False, 'missing': True, 'status_details': ['下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '施军', 'department': '财务部', 'date': '2025-06-2', 'morning_start': datetime.time(7, 48), 'morning_end': datetime.time(17, 38), 'afternoon_start': None, 'afternoon_end': None, 'late': False, 'early_leave': False, 'missing': True, 'status_details': ['下午上班缺卡', '下午下班缺卡']}
#
# date_str: 3
# date: 2025-06-3
# times: [datetime.time(13, 42), datetime.time(17, 33)]
# valid_times: [datetime.time(13, 42), datetime.time(17, 33)]
# num_times == 2: 13:42:00 17:33:00
# 08:00:00 12:00:00 13:00:00 15:30:00
# periods: {'morning_start': datetime.time(13, 42), 'morning_end': datetime.time(17, 33), 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': True, 'early_leave': False, 'missing': True, 'status_details': ['上午迟到', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '施军', 'department': '财务部', 'date': '2025-06-3', 'morning_start': datetime.time(13, 42), 'morning_end': datetime.time(17, 33), 'afternoon_start': None, 'afternoon_end': None, 'late': True, 'early_leave': False, 'missing': True, 'status_details': ['上午迟到', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 4
# date: 2025-06-4
# times: [datetime.time(13, 44), datetime.time(17, 33)]
# valid_times: [datetime.time(13, 44), datetime.time(17, 33)]
# num_times == 2: 13:44:00 17:33:00
# 08:00:00 12:00:00 13:00:00 15:30:00
# periods: {'morning_start': datetime.time(13, 44), 'morning_end': datetime.time(17, 33), 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': True, 'early_leave': False, 'missing': True, 'status_details': ['上午迟到', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '施军', 'department': '财务部', 'date': '2025-06-4', 'morning_start': datetime.time(13, 44), 'morning_end': datetime.time(17, 33), 'afternoon_start': None, 'afternoon_end': None, 'late': True, 'early_leave': False, 'missing': True, 'status_details': ['上午迟到', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 5
# date: 2025-06-5
# ...
# periods: {'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 32)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '2025-06-10', 'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 32), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 11
# date: 2025-06-11
# times: [datetime.time(7, 53), datetime.time(12, 2), datetime.time(12, 31), datetime.time(17, 41)]
# valid_times: [datetime.time(7, 53), datetime.time(12, 2), datetime.time(12, 31), datetime.time(17, 41)]
# periods: {'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 2), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 41)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '2025-06-11', 'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 2), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 41), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 12
# date: 2025-06-12
# times: [datetime.time(7, 55), datetime.time(12, 5), datetime.time(12, 31), datetime.time(17, 38)]
# valid_times: [datetime.time(7, 55), datetime.time(12, 5), datetime.time(12, 31), datetime.time(17, 38)]
# periods: {'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 5), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 38)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '2025-06-12', 'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 5), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 38), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 13
# date: 2025-06-13
# times: [datetime.time(7, 53), datetime.time(12, 6), datetime.time(12, 59), datetime.time(17, 50)]
# valid_times: [datetime.time(7, 53), datetime.time(12, 6), datetime.time(12, 59), datetime.time(17, 50)]
# periods: {'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 6), 'afternoon_start': datetime.time(12, 59), 'afternoon_end': datetime.time(17, 50)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '2025-06-13', 'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 6), 'afternoon_start': datetime.time(12, 59), 'afternoon_end': datetime.time(17, 50), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 六.1
# date: 特殊日期_15
# times: [datetime.time(7, 51), datetime.time(12, 4), datetime.time(12, 31), datetime.time(17, 39)]
# valid_times: [datetime.time(7, 51), datetime.time(12, 4), datetime.time(12, 31), datetime.time(17, 39)]
# periods: {'morning_start': datetime.time(7, 51), 'morning_end': datetime.time(12, 4), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 39)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '特殊日期_15', 'morning_start': datetime.time(7, 51), 'morning_end': datetime.time(12, 4), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 39), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 日.2
# date: 特殊日期_16
# times: []
# valid_times: []
# periods: {'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '特殊日期_16', 'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None, 'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 16
# date: 2025-06-16
# times: [datetime.time(7, 49), datetime.time(12, 1), datetime.time(12, 32), datetime.time(17, 34)]
# valid_times: [datetime.time(7, 49), datetime.time(12, 1), datetime.time(12, 32), datetime.time(17, 34)]
# periods: {'morning_start': datetime.time(7, 49), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 34)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '2025-06-16', 'morning_start': datetime.time(7, 49), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 34), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 17
# date: 2025-06-17
# times: [datetime.time(7, 53), datetime.time(12, 12), datetime.time(12, 31), datetime.time(17, 40)]
# valid_times: [datetime.time(7, 53), datetime.time(12, 12), datetime.time(12, 31), datetime.time(17, 40)]
# periods: {'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 12), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 40)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '2025-06-17', 'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 12), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 40), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 18
# date: 2025-06-18
# times: [datetime.time(7, 53), datetime.time(12, 14), datetime.time(12, 32), datetime.time(17, 32)]
# valid_times: [datetime.time(7, 53), datetime.time(12, 14), datetime.time(12, 32), datetime.time(17, 32)]
# periods: {'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 14), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 32)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '2025-06-18', 'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 14), 'afternoon_start': datetime.time(12, 32), 'afternoon_end': datetime.time(17, 32), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 19
# date: 2025-06-19
# times: [datetime.time(7, 56), datetime.time(12, 14), datetime.time(12, 31), datetime.time(17, 37)]
# valid_times: [datetime.time(7, 56), datetime.time(12, 14), datetime.time(12, 31), datetime.time(17, 37)]
# periods: {'morning_start': datetime.time(7, 56), 'morning_end': datetime.time(12, 14), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 37)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '2025-06-19', 'morning_start': datetime.time(7, 56), 'morning_end': datetime.time(12, 14), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 37), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 20
# date: 2025-06-20
# times: [datetime.time(7, 55), datetime.time(12, 12), datetime.time(12, 31), datetime.time(17, 31)]
# valid_times: [datetime.time(7, 55), datetime.time(12, 12), datetime.time(12, 31), datetime.time(17, 31)]
# periods: {'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 12), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 31)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '2025-06-20', 'morning_start': datetime.time(7, 55), 'morning_end': datetime.time(12, 12), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 31), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 六.2
# date: 特殊日期_22
# times: [datetime.time(7, 54), datetime.time(12, 18), datetime.time(13, 26), datetime.time(17, 53)]
# valid_times: [datetime.time(7, 54), datetime.time(12, 18), datetime.time(13, 26), datetime.time(17, 53)]
# periods: {'morning_start': datetime.time(7, 54), 'morning_end': datetime.time(12, 18), 'afternoon_start': datetime.time(13, 26), 'afternoon_end': datetime.time(17, 53)}
# status: {'late': True, 'early_leave': False, 'missing': False, 'status_details': ['下午迟到']}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '特殊日期_22', 'morning_start': datetime.time(7, 54), 'morning_end': datetime.time(12, 18), 'afternoon_start': datetime.time(13, 26), 'afternoon_end': datetime.time(17, 53), 'late': True, 'early_leave': False, 'missing': False, 'status_details': ['下午迟到']}
#
# date_str: 日.3
# date: 特殊日期_23
# times: []
# valid_times: []
# periods: {'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '特殊日期_23', 'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None, 'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 23
# date: 2025-06-23
# times: [datetime.time(7, 53), datetime.time(12, 1), datetime.time(12, 31), datetime.time(17, 38)]
# valid_times: [datetime.time(7, 53), datetime.time(12, 1), datetime.time(12, 31), datetime.time(17, 38)]
# periods: {'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 38)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '2025-06-23', 'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 1), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 38), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 24
# date: 2025-06-24
# times: [datetime.time(7, 52), datetime.time(12, 13), datetime.time(12, 31), datetime.time(17, 52)]
# valid_times: [datetime.time(7, 52), datetime.time(12, 13), datetime.time(12, 31), datetime.time(17, 52)]
# periods: {'morning_start': datetime.time(7, 52), 'morning_end': datetime.time(12, 13), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 52)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '2025-06-24', 'morning_start': datetime.time(7, 52), 'morning_end': datetime.time(12, 13), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 52), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 25
# date: 2025-06-25
# times: [datetime.time(7, 53), datetime.time(12, 2), datetime.time(12, 37), datetime.time(18, 37)]
# valid_times: [datetime.time(7, 53), datetime.time(12, 2), datetime.time(12, 37), datetime.time(18, 37)]
# periods: {'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 2), 'afternoon_start': datetime.time(12, 37), 'afternoon_end': datetime.time(18, 37)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '2025-06-25', 'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 2), 'afternoon_start': datetime.time(12, 37), 'afternoon_end': datetime.time(18, 37), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 26
# date: 2025-06-26
# times: [datetime.time(7, 53), datetime.time(12, 13), datetime.time(12, 42), datetime.time(20, 32), datetime.time(20, 33)]
# valid_times: [datetime.time(7, 53), datetime.time(12, 13), datetime.time(12, 42), datetime.time(20, 32), datetime.time(20, 33)]
# periods: {'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 13), 'afternoon_start': datetime.time(12, 42), 'afternoon_end': datetime.time(20, 32)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '2025-06-26', 'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 13), 'afternoon_start': datetime.time(12, 42), 'afternoon_end': datetime.time(20, 32), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 27
# date: 2025-06-27
# times: [datetime.time(7, 54), datetime.time(12, 12), datetime.time(12, 37), datetime.time(17, 50)]
# valid_times: [datetime.time(7, 54), datetime.time(12, 12), datetime.time(12, 37), datetime.time(17, 50)]
# periods: {'morning_start': datetime.time(7, 54), 'morning_end': datetime.time(12, 12), 'afternoon_start': datetime.time(12, 37), 'afternoon_end': datetime.time(17, 50)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '2025-06-27', 'morning_start': datetime.time(7, 54), 'morning_end': datetime.time(12, 12), 'afternoon_start': datetime.time(12, 37), 'afternoon_end': datetime.time(17, 50), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 六.3
# date: 特殊日期_29
# times: [datetime.time(7, 59), datetime.time(12, 6), datetime.time(12, 31), datetime.time(17, 32)]
# valid_times: [datetime.time(7, 59), datetime.time(12, 6), datetime.time(12, 31), datetime.time(17, 32)]
# periods: {'morning_start': datetime.time(7, 59), 'morning_end': datetime.time(12, 6), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 32)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '特殊日期_29', 'morning_start': datetime.time(7, 59), 'morning_end': datetime.time(12, 6), 'afternoon_start': datetime.time(12, 31), 'afternoon_end': datetime.time(17, 32), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
#
# date_str: 日.4
# date: 特殊日期_30
# times: []
# valid_times: []
# periods: {'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None}
# status: {'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '特殊日期_30', 'morning_start': None, 'morning_end': None, 'afternoon_start': None, 'afternoon_end': None, 'late': False, 'early_leave': False, 'missing': True, 'status_details': ['上午上班缺卡', '上午下班缺卡', '下午上班缺卡', '下午下班缺卡']}
#
# date_str: 30
# date: 2025-06-30
# times: [datetime.time(7, 53), datetime.time(12, 12), datetime.time(12, 36), datetime.time(17, 38)]
# valid_times: [datetime.time(7, 53), datetime.time(12, 12), datetime.time(12, 36), datetime.time(17, 38)]
# periods: {'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 12), 'afternoon_start': datetime.time(12, 36), 'afternoon_end': datetime.time(17, 38)}
# status: {'late': False, 'early_leave': False, 'missing': False, 'status_details': []}
# record: {'employee': '卫良金', 'department': '质量与工艺部-工艺处', 'date': '2025-06-30', 'morning_start': datetime.time(7, 53), 'morning_end': datetime.time(12, 12), 'afternoon_start': datetime.time(12, 36), 'afternoon_end': datetime.time(17, 38), 'late': False, 'early_leave': False, 'missing': False, 'status_details': []}

# %%
result_df = pd.DataFrame(results)

# %%
detailed_report = result_df.rename(columns={
    'employee': '员工姓名',
    'date': '日期',
    'morning_start': '上午上班',
    'morning_end': '上午下班',
    'afternoon_start': '下午上班',
    'afternoon_end': '下午下班',
    'late': '迟到',
    'early_leave': '早退',
    'missing': '缺卡'
})
detailed_report
# Out:
#     员工姓名  department          日期      上午上班      上午下班      下午上班      下午下班  \
# 0     刘旸         财务部      特殊日期_2      None      None      None      None
# 1     刘旸         财务部   2025-06-2  07:35:00  12:08:00  12:31:00  17:31:00
# 2     刘旸         财务部   2025-06-3  07:35:00  12:12:00  12:32:00  17:33:00
# 3     刘旸         财务部   2025-06-4  07:35:00  12:11:00  12:31:00  17:33:00
# 4     刘旸         财务部   2025-06-5  07:40:00  12:11:00  12:31:00  17:32:00
# ..   ...         ...         ...       ...       ...       ...       ...
# 775  卫良金  质量与工艺部-工艺处  2025-06-26  07:53:00  12:13:00  12:42:00  20:32:00
# 776  卫良金  质量与工艺部-工艺处  2025-06-27  07:54:00  12:12:00  12:37:00  17:50:00
# 777  卫良金  质量与工艺部-工艺处     特殊日期_29  07:59:00  12:06:00  12:31:00  17:32:00
# 778  卫良金  质量与工艺部-工艺处     特殊日期_30      None      None      None      None
# 779  卫良金  质量与工艺部-工艺处  2025-06-30  07:53:00  12:12:00  12:36:00  17:38:00
#
#         迟到     早退     缺卡                    status_details
# 0    False  False   True  [上午上班缺卡, 上午下班缺卡, 下午上班缺卡, 下午下班缺卡]
# 1    False  False  False                                []
# 2    False  False  False                                []
# 3    False  False  False                                []
# 4    False  False  False                                []
# ..     ...    ...    ...                               ...
# 775  False  False  False                                []
# 776  False  False  False                                []
# 777  False  False  False                                []
# 778  False  False   True  [上午上班缺卡, 上午下班缺卡, 下午上班缺卡, 下午下班缺卡]
# 779  False  False  False                                []
#
# [780 rows x 11 columns]

# %%
detailed_report= detailed_report[detailed_report['status_details'].apply(len) > 0]
detailed_report
# Out:
#     员工姓名  department       日期      上午上班      上午下班      下午上班      下午下班     迟到  \
# 0     刘旸         财务部   特殊日期_2      None      None      None      None  False
# 7     刘旸         财务部   特殊日期_9      None      None      None      None  False
# 14    刘旸         财务部  特殊日期_16      None      None      None      None  False
# 21    刘旸         财务部  特殊日期_23      None      None      None      None  False
# 28    刘旸         财务部  特殊日期_30      None      None      None      None  False
# ..   ...         ...      ...       ...       ...       ...       ...    ...
# 757  卫良金  质量与工艺部-工艺处   特殊日期_9      None      None      None      None  False
# 764  卫良金  质量与工艺部-工艺处  特殊日期_16      None      None      None      None  False
# 770  卫良金  质量与工艺部-工艺处  特殊日期_22  07:54:00  12:18:00  13:26:00  17:53:00   True
# 771  卫良金  质量与工艺部-工艺处  特殊日期_23      None      None      None      None  False
# 778  卫良金  质量与工艺部-工艺处  特殊日期_30      None      None      None      None  False
#
#         早退     缺卡                    status_details
# 0    False   True  [上午上班缺卡, 上午下班缺卡, 下午上班缺卡, 下午下班缺卡]
# 7    False   True  [上午上班缺卡, 上午下班缺卡, 下午上班缺卡, 下午下班缺卡]
# 14   False   True  [上午上班缺卡, 上午下班缺卡, 下午上班缺卡, 下午下班缺卡]
# 21   False   True  [上午上班缺卡, 上午下班缺卡, 下午上班缺卡, 下午下班缺卡]
# 28   False   True  [上午上班缺卡, 上午下班缺卡, 下午上班缺卡, 下午下班缺卡]
# ..     ...    ...                               ...
# 757  False   True  [上午上班缺卡, 上午下班缺卡, 下午上班缺卡, 下午下班缺卡]
# 764  False   True  [上午上班缺卡, 上午下班缺卡, 下午上班缺卡, 下午下班缺卡]
# 770  False  False                            [下午迟到]
# 771  False   True  [上午上班缺卡, 上午下班缺卡, 下午上班缺卡, 下午下班缺卡]
# 778  False   True  [上午上班缺卡, 上午下班缺卡, 下午上班缺卡, 下午下班缺卡]
#
# [541 rows x 11 columns]
